# %%
from nltk.corpus import wordnet

# %%
x = wordnet.synsets('create')
x
# Out:
# [Synset('make.v.03'),
#  Synset('create.v.02'),
#  Synset('create.v.03'),
#  Synset('create.v.04'),
#  Synset('create.v.05'),
#  Synset('produce.v.02')]

# %%
x[5].lemmas()[0].name()
# Out:
# 'produce'

# %%
synonyms = set()

for word in wordnet.synsets('create'):
    synonyms.add(word.lemmas()[0].name())

synonyms
# Out:
# {'create', 'make', 'produce'}

# %%
synonyms = set()

for word in wordnet.synsets('produce'):
    synonyms.add(word.lemmas()[0].name())

synonyms
# Out:
# {'grow', 'produce'}

# %%
synonyms = set()

for word in wordnet.synsets('make'):
    synonyms.add(word.lemmas()[0].name())

synonyms
# Out:
# {'brand',
#  'cause',
#  'construct',
#  'cook',
#  'create',
#  'do',
#  'draw',
#  'form',
#  'gain',
#  'have',
#  'hold',
#  'induce',
#  'lay_down',
#  'make',
#  'name',
#  'produce',
#  'reach',
#  'seduce',
#  'shuffle',
#  'stool',
#  'take'}

# %%
for w in wordnet.synsets('make'):
    print(w.lemmas()[0].name())
# Out:
# brand
# shuffle
# make
# make
# make
# induce
# cause
# produce
# draw
# make
# create
# gain
# do
# form
# reach
# make
# make
# make
# construct
# make
# make
# name
# have
# reach
# lay_down
# make
# make
# hold
# make
# take
# stool
# make
# make
# make
# make
# make
# make
# make
# make
# make
# cook
# seduce
# make
# make
# make
# make
# make
# make
# make
# make
# make

# %%
word = wordnet.synsets('post')
print('Word and PoS: ', word[0].name())
print('Synonym: ', word[0].lemmas()[1].name())
print('Meaning: ', word[0].definition())
print('Example: ', word[0].examples())
# Out:
# Word and PoS:  post.n.01
# Synonym:  station
# Meaning:  the position where someone (as a guard or sentry) stands or is assigned to stand
# Example:  ['a soldier manned the entrance post', 'a sentry station']

# %%
word = wordnet.synsets('post')
print('Word and PoS: ', word[1].name())
print('Synonym: ', word[1].lemmas()[1].name())
print('Meaning: ', word[1].definition())
print('Example: ', word[1].examples())
# Out:
# Word and PoS:  military_post.n.01
# Synonym:  post
# Meaning:  military installation at which a body of troops is stationed
# Example:  ['this military post provides an important source of income for the town nearby', "there is an officer's club on the post"]

# %%
word = wordnet.synsets('good')
print('Word and PoS: ', word[1].name())
print('Synonym: ', word[1].lemmas()[1].name())
print('Meaning: ', word[1].definition())
print('Example: ', word[1].examples())
# Out:
# Word and PoS:  good.n.02
# Synonym:  goodness
# Meaning:  moral excellence or admirableness
# Example:  ['there is much good to be found in people']

# %%
word
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.04'),
#  Synset('good.a.03'),
#  Synset('estimable.s.01'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.04'),
#  Synset('good.s.05'),
#  Synset('adept.s.01'),
#  Synset('good.s.07'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.03'),
#  Synset('good.s.10'),
#  Synset('good.s.11'),
#  Synset('effective.s.03'),
#  Synset('good.s.13'),
#  Synset('good.s.14'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
for word in wordnet.synsets('sound', pos='v'):
    print(word.name())
# Out:
# sound.v.01
# sound.v.02
# sound.v.03
# sound.v.04
# voice.v.02
# sound.v.06
# fathom.v.02

# %%
for word in wordnet.synsets('sound', pos='n'):
    print(word.name())
# Out:
# sound.n.01
# sound.n.02
# sound.n.03
# sound.n.04
# audio.n.01
# phone.n.02
# strait.n.01
# sound.n.08

# %% [markdown]
# ### Q. Read a word from user and find all meaning of this word

# %%
word = input("Enter a word: ")
for w in wordnet.synsets(word):
    print('word:',word," -> defination: ",w.definition())

# %% [markdown]
# ### Q. Read a word from user and find all meaning of this word(NOUN MEANINGS)

# %%
word = input('Enter a word: ')
for w in wordnet.synsets(word, pos='n'):
    
    print('word: ', w, ' definition: ', w.definition())

# %% [markdown]
# ### Q. Extract specific POS from the word

# %%
verbs = set()
nouns = set()
adjts = set()

for w in wordnet.synsets('sound'):
    if w.pos() == 'n':
        nouns.add(w.lemmas()[0].name())
    if w.pos() == 'v':
        verbs.add(w.lemmas()[0].name())
    if w.pos() == 'a':
        adjts.add(w.lemmas()[0].name())

print(verbs)
print(adjts)
print(nouns)
# Out:
# {'fathom', 'sound', 'voice'}
# {'sound'}
# {'strait', 'audio', 'sound', 'phone'}

# %% [markdown]
# ### Extract antonyms

# %%
antonyms = set()

for word in wordnet.synsets('peak'):
    for lemma in word.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

antonyms
# Out:
# {'bottom_out'}

# %% [markdown]
# ### Extract hypernyms

# %%
word = 'isis'
synsets = wordnet.synsets(word)

for x in synsets:
    hypernyms = x.hypernyms()
    for h in hypernyms:
        print(word, ' -- hypernym of -- ', h.name())
# Out:
# isis  -- hypernym of --  international_intelligence_agency.n.01

# %% [markdown]
# ### Extract meronymns

# %%
word = 'car'
synsets = wordnet.synsets(word)

for x in synsets:
    meronyms = x.part_meronyms()
    for m in meronyms:
        print(word, 'meronyms of', m.name())
# Out:
# car meronyms of accelerator.n.01
# car meronyms of first_gear.n.01
# car meronyms of car_mirror.n.01
# car meronyms of stabilizer_bar.n.01
# car meronyms of car_door.n.01
# car meronyms of reverse.n.02
# car meronyms of bumper.n.02
# car meronyms of car_seat.n.01
# car meronyms of high_gear.n.01
# car meronyms of window.n.02
# car meronyms of third_gear.n.01
# car meronyms of tail_fin.n.02
# car meronyms of running_board.n.01
# car meronyms of air_bag.n.01
# car meronyms of hood.n.09
# car meronyms of luggage_compartment.n.01
# car meronyms of automobile_engine.n.01
# car meronyms of roof.n.02
# car meronyms of auto_accessory.n.01
# car meronyms of gasoline_engine.n.01
# car meronyms of car_window.n.01
# car meronyms of automobile_horn.n.01
# car meronyms of sunroof.n.01
# car meronyms of buffer.n.06
# car meronyms of fender.n.01
# car meronyms of rear_window.n.01
# car meronyms of floorboard.n.02
# car meronyms of glove_compartment.n.01
# car meronyms of grille.n.02
# ...

# %%
word = 'car'
synsets = wordnet.synsets(word)

for x in synsets:
    holo = x.part_holonyms()
    for m in holo:
        print(word, 'holo of', m.name())
# Out:
# car holo of airship.n.01
# car holo of elevator.n.01
# car holo of cable_railway.n.01
