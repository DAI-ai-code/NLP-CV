# %%
pip install pypdf spire.doc
# Out:
# ...
#    ---------------------------------------- 0.0/28.9 MB ? eta -:--:--
#    --------------------------- ------------ 19.9/28.9 MB 96.9 MB/s eta 0:00:01
#    ---------------------------------------  28.8/28.9 MB 87.1 MB/s eta 0:00:01
#    ---------------------------------------- 28.9/28.9 MB 68.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#    ------------- -------------------------- 1/3 [plum-dispatch]
#    ------------- -------------------------- 1/3 [plum-dispatch]
#    -------------------------- ------------- 2/3 [spire.doc]
# ...

# %% [markdown]
# ### Read from PDF

# %%
from pypdf import PdfReader

reader = PdfReader('../input/course.pdf')

# %%
reader.pages[0];
len(reader.pages)
# Out:
# 3

# %%
page1 = reader.pages[0]
print(page1.extract_text())
# Out:
#       DECCAN COLLEGE Post-Graduate and Research Institute Pune 411006 [Declared as deemed to be University under Section 3 of UGC Act 1956]  ADMISSION NOTICE: 2024 [NOTICE NO. AS/2024/1331] I. Admissions are open for the following courses for the year 2024  1. ONLINE Advanced Certificate course RQ µ3\WKRQ 3URJUDPPLQJ IRU &RPSXWDWLRQDO/LQJXLVWLFVDQG1DWXUDO/DQJXDJH3URFHVVLQJ¶ (Please check detailed course information in Annexure-I below.)  x Duration:2 months (30 hrs: 2 Credits)  x Intake Capacity:20 seats  x Last date of Registration: 1st May 2024  x Eligibility:10+2 or equivalent from any recognised institute AND have (i) OR (ii) mentioned below; i6KRXOGKDYHFRPSOHWHGWKHFHUWLILFDWHFRXUVHRQ³3\WKRQ3URJUDPPLQJIRU1/3DQG&RPSXWDWLRQDO /LQJXLVWLFV´ MRLQWO\ RIIHUHG E\ 'HFFDQ &ROOHJH 3RVW-Graduate Research Institute, Pune and MITU Skillologies, Pune.  OR ii) Should have - 9 Practical knowledge of Python Programming 9 Basics of NLP through Python Programming 9 Basic mathematical reasoning  Note
# ...

# %%
for page in reader.pages:
    print(page.extract_text())
# Out:
#       DECCAN COLLEGE Post-Graduate and Research Institute Pune 411006 [Declared as deemed to be University under Section 3 of UGC Act 1956]  ADMISSION NOTICE: 2024 [NOTICE NO. AS/2024/1331] I. Admissions are open for the following courses for the year 2024  1. ONLINE Advanced Certificate course RQ µ3\WKRQ 3URJUDPPLQJ IRU &RPSXWDWLRQDO/LQJXLVWLFVDQG1DWXUDO/DQJXDJH3URFHVVLQJ¶ (Please check detailed course information in Annexure-I below.)  x Duration:2 months (30 hrs: 2 Credits)  x Intake Capacity:20 seats  x Last date of Registration: 1st May 2024  x Eligibility:10+2 or equivalent from any recognised institute AND have (i) OR (ii) mentioned below; i6KRXOGKDYHFRPSOHWHGWKHFHUWLILFDWHFRXUVHRQ³3\WKRQ3URJUDPPLQJIRU1/3DQG&RPSXWDWLRQDO /LQJXLVWLFV´ MRLQWO\ RIIHUHG E\ 'HFFDQ &ROOHJH 3RVW-Graduate Research Institute, Pune and MITU Skillologies, Pune.  OR ii) Should have - 9 Practical knowledge of Python Programming 9 Basics of NLP through Python Programming 9 Basic mathematical reasoning  Note
# ...
