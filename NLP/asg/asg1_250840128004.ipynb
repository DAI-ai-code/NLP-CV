# %% [markdown]
# # Assignment 1

# %% [markdown]
# Q.1
# sent = 'They told that their ages are 23, 25 and 29 respectively.'
#  1. Find the average of ages.

# %%
from nltk.tokenize import word_tokenize
sent = 'They told that their ages are 23, 25 and 29 respectively.'
tokens = word_tokenize(sent)
ages = [int(i) for i in tokens if i.isnumeric()]
avg = sum(ages) / len(ages)
avg
# Out:
# 25.666666666666668

# %% [markdown]
#  2. Count total number of words starts with 't' / 'T'

# %%
t_s = [i for i in tokens if i.lower().startswith('t')]
len(t_s)
# Out:
# 4

# %% [markdown]
#  3. Count total punctuation symbols.

# %%
from nltk import WordPunctTokenizer
puncs = WordPunctTokenizer()
p = puncs.tokenize(sent)
print(p)
p = [i for i in p if not i.isalpha() and not i.isnumeric()]
p
# Out:
# ['They', 'told', 'that', 'their', 'ages', 'are', '23', ',', '25', 'and', '29', 'respectively', '.']
# [',', '.']

# %% [markdown]
#  4. Print the words in capital letter which ends with 'd'

# %%
from nltk import word_tokenize
sent = 'They told that their ages are 23, 25 and 29 respectively.'
tokens = word_tokenize(sent)
caps = [i.upper() for i in tokens if i.endswith('d')]
caps
# Out:
# ['TOLD', 'AND']

# %% [markdown]
#  5. Merge all the words and print (no punctuations)

# %%
from nltk import word_tokenize
sent = 'They told that their ages are 23, 25 and 29 respectively.'
tokens = word_tokenize(sent)
words = [i for i in tokens if i.isalpha() or i.isnumeric()]
words = " ".join(words)
words
# Out:
# 'They told that their ages are 23 25 and 29 respectively'

# %% [markdown]
# Q.2 : Open the wikipedia page of Indian flag and perform following analysis

# %% [markdown]
# 2. Count total number of Words

# %%
text = '''India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.[22][23][24] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia.

Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[26][27][28] Their long occupation, predominantly in isolation as hunter-gatherers, has made the region highly diverse.[29] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the Indus Valley Civilisation of the third millennium BCE.[30] By 1200 BCE, an archaic form of Sanskrit, an Indo-European language, had diffused into India from the northwest.[31][32] Its hymns recorded the early dawnings of Hinduism in India.[33] India's pre-existing Dravidian languages were supplanted in the northern regions.[34] By 400 BCE, caste had emerged within Hinduism,[35] and Buddhism and Jainism had arisen, proclaiming social orders unlinked to heredity.[36] Early political consolidations gave rise to the loose-knit Maurya and Gupta Empires.[37] Widespread creativity suffused this era,[38] but the status of women declined,[39] and untouchability became an organised belief.[l][40] In South India, the Middle kingdoms exported Dravidian language scripts and religious cultures to the kingdoms of Southeast Asia.[41]'''

from nltk.tokenize import word_tokenize
words = word_tokenize(text)
total = len(words)
total
# Out:
# 389

# %% [markdown]
# 3. Count percentage of punctuation marks

# %%
puncs = [i for i in words if not i.isalpha() and not i.isnumeric()]
percentage = len(puncs) / total 
percentage*100
# Out:
# 25.70694087403599

# %% [markdown]
# 4. Print total number of lines

# %%
from nltk.tokenize import sent_tokenize
sents = sent_tokenize(text)
len(sents)
# Out:
# 15

# %% [markdown]
# 6. Remove the numbers and print the text

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(text)

just_text = [i for i in words if i.isalpha()]
just_text = " ".join(just_text)
just_text
# Out:
# 'India officially the Republic of India j is a country in South Asia It is the country by area the most populous country since and since its independence in the world most populous democracy Bounded by the Indian Ocean on the south the Arabian Sea on the southwest and the Bay of Bengal on the southeast it shares land borders with Pakistan to the west k China Nepal and Bhutan to the north and Bangladesh and Myanmar to the east In the Indian Ocean India is near Sri Lanka and the Maldives its Andaman and Nicobar Islands share a maritime border with Myanmar Thailand and Indonesia Modern humans arrived on the Indian subcontinent from Africa no later than years ago Their long occupation predominantly in isolation as has made the region highly diverse Settled life emerged on the subcontinent in the western margins of the Indus river basin years ago evolving gradually into the Indus Valley Civilisation of the third millennium BCE By BCE an archaic form of Sanskrit an language had diffused into India from the northwest Its hymns recorded the early dawnings of Hinduism in India India Dravidian languages were supplanted in the northern regions By BCE caste had emerged within Hinduism and Buddhism and Jainism had arisen proclaiming social orders unlinked to heredity Early political consolidations gave rise to the Maurya and Gupta Empires Widespread creativity suffused this era but the status of women declined and untouchability became an organised belief l In South India the Middle kingdoms exported Dravidian language scripts and religious cultures to the kingdoms of Southeast Asia'
