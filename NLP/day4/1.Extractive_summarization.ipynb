# %% [markdown]
# ## **Lex Rank Summarizer**

# %%
from sumy.summarizers.lex_rank import LexRankSummarizer

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from nltk.tokenize import sent_tokenize

# %%
lex_rank_summarizer = LexRankSummarizer()
text_parser = PlaintextParser.from_string(text, Tokenizer("english"))

# %%
lex_Summary = lex_rank_summarizer(text_parser.document,sentences_count=3)

# %%
lex_Summary
# Out:
# (<Sentence: It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes.>,
#  <Sentence: It is listed as Endangered on the IUCN Red List of Threatened Species, as its range is thought to have declined by 53% to 68% since the late 1990s.>,
#  <Sentence: In several range countries, wildlife corridors have been established and tiger reintroduction is planned.>)

# %% [markdown]
# ## **LSA Summarizer**

# %%
lsa_summarizer =LsaSummarizer()

# %%
text_parser = PlaintextParser.from_string(text,Tokenizer("english"))

# %%
lsa_summary = lsa_summarizer(text_parser.document,sentences_count=5)

# %%
lsa_summary
# Out:
# (<Sentence: The tiger is an apex predator and preys mainly on ungulates, which it takes by ambush.>,
#  <Sentence: It lives a mostly solitary life and occupies home ranges, defending these from individuals of the same sex.>,
#  <Sentence: It is listed as Endangered on the IUCN Red List of Threatened Species, as its range is thought to have declined by 53% to 68% since the late 1990s.>,
#  <Sentence: National conservation measures consist of action plans, anti-poaching patrols and schemes for monitoring tiger populations.>,
#  <Sentence: In several range countries, wildlife corridors have been established and tiger reintroduction is planned.>)
